# %% [markdown]
# # Cours "Traitement informatique des données" - premier semestre
# ### Louis Maritaud
# ### louis.maritaud@unilim.fr

# %% [markdown]
# ## Objectifs pédagogiques
# - Comprendre les bases de python :
#     * Lien avec les SHS
#     * Types de données
#     * Structures de données
#     * DataFrames - tableaux
# - Applications à des données pré-existantes
#
# ------
# # Modalités d'examen
# ## Examen teminal : **dossier à déposer sur Moodle/envoi par mail**
# Dossier "projet" :
# - Sur la base d'une *problématique de recherche*, produire une *chaîne de traitement des données* en utilisant Python.
# Dossier structuré :
#     - Introduction présentant la problématique de recherche
#     - Problématisation du traitement des données
#         → Intérêt en lien avec votre problématique
#         → Solutions alternatives : qu'est-ce que j'aurais pu faire en dehors de Python pour atteindre l'objectif ?
#         → Réflexion en première instance de mise en oeuvre : au départ, je comptais faire ça comme ça, puis ça comme ça etc.
#     - Explication des différentes manipulations de données via Python, *avec vos mots*
#     - Présentation des résultats
#     - Conclusion / ouverture sur d'autres traitements de données
#
# * Dossier comprenant :
#     * Le **code** sous format .ipynb, ou via google collabs
#     * Une partie écrite, qui pourra être dans le notebook directement ou en format pdf
#
# ## Barème :
# <table border="1" cellspacing="0" cellpadding="6">
#
#   <tr>
#     <th colspan="7">Partie écrite</th>
#     <th colspan="4">Code</th>
#   </tr>
#   <tr>
#     <th>Intro avec problématique</th>
#     <th>Intérêt du traitement</th>
#     <th>Solutions alternatives</th>
#     <th>Réflexion en première instance de mise en œuvre</th>
#     <th>Différentes manip en Python</th>
#     <th>Présentation des résultats</th>
#     <th>Conclusion / ouverture</th>
#     <th>Complexité du code</th>
#     <th>Cohérence code / explications</th>
#     <th>Cohérence problématique / traitement</th>
#     <th>Clarté du code</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>1</td>
#     <td>1</td>
#     <td>2</td>
#     <td>2</td>
#     <td>2</td>
#     <td>1</td>
#     <td>2</td>
#     <td>4</td>
#     <td>2</td>
#     <td>2</td>
#   </tr>
#
# </table>
#
#
# ## Important !
# * Si vous utilisez un outil d'intelligence artificielle, je le saurai, et ce n'est pas autorisé. L'intérêt n'est pas du tout que vous deveniez des programmeurs de génie, mais que vous compreniez :
#     - 1- Ce que vous faites ;
#     - 2- Comment vous le faites et
#     - 3- Ce que le traitement des données via un outil de programmation peut vous apporter.
# * Vous n'avez pas besoin de m'écrire des notebooks extrêmement compliqués. Ce que j'attends et que j'évaluerai principalement, c'est votre aptitude à traiter des données, pas votre compétence en programmation.
# * N'hésitez pas à faire des cellules de code entrecoupées de cellules de texte : c'est plus lisible et compréhensible
# * Pour vous évaluer, je lancerai l'intégralité de votre code. Si certaines cellules ne fonctionnent pas, je débugguerai si besoin, mais je saurai aussi d'où vient l'erreur, ce qui peut m'amener à considérer que vous n'avez simplement pas fait le travail vous mêmes.
# --------
# # Accès aux cours
# * Cours 1 - Pemiers pas [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/Lmarito/Histoire_M1/main?urlpath=%2Fdoc%2Ftree%2FS1%2FCours_1-Premiers_pas.ipynb)
# * Cours 2 - Structures de données [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/Lmarito/Histoire_M1/main?urlpath=%2Fdoc%2Ftree%2FS1%2FCours_2-Structures_de_donnees.ipynb)
# * Cours 3 - Boucles et conditions [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/Lmarito/Histoire_M1/main?urlpath=%2Fdoc%2Ftree%2FS1%2FCours_3-Boucles_conditions.ipynb)
# * Cours 4 - DataFrames [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/Lmarito/Histoire_M1/main?urlpath=%2Fdoc%2Ftree%2FS1%2FCours_4-DataFrames.ipynb)
# * Cours 5 - Applications - 1 [![Binder](https://mybinder.org/badge_logo.svg)](https://mybinder.org/v2/gh/Lmarito/Histoire_M1/main?urlpath=%2Fdoc%2Ftree%2FS1%2FCours_5-Applications-1.ipynb)
